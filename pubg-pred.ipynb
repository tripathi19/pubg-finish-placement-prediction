# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/pubg-finish-placement-prediction/test_V2.csv
# /kaggle/input/pubg-finish-placement-prediction/train_V2.csv
# /kaggle/input/pubg-finish-placement-prediction/sample_submission_V2.csv

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df


def import_data(file):
    """create a dataframe and optimize its memory usage"""
    df = pd.read_csv(file, parse_dates=True, keep_date_col=True)
    df = reduce_mem_usage(df)
    return df

# %%
print('-' * 80)
print('train')
train = import_data('/kaggle/input/pubg-finish-placement-prediction/train_V2.csv')

print('-' * 80)
print('test')
test = import_data('/kaggle/input/pubg-finish-placement-prediction/test_V2.csv')
# Out:
# --------------------------------------------------------------------------------
# train
# Memory usage of dataframe is 983.90 MB
# Memory usage after optimization is: 498.81 MB
# Decreased by 49.3%
# --------------------------------------------------------------------------------
# test
# Memory usage of dataframe is 413.18 MB
# Memory usage after optimization is: 225.31 MB
# Decreased by 45.5%

# %%
train.shape
# Out:
# (4446966, 29)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4446966 entries, 0 to 4446965
# Data columns (total 29 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Id               category
#  1   groupId          category
#  2   matchId          category
#  3   assists          int8
#  4   boosts           int8
#  5   damageDealt      float16
#  6   DBNOs            int8
#  7   headshotKills    int8
#  8   heals            int8
#  9   killPlace        int8
#  10  killPoints       int16
#  11  kills            int8
#  12  killStreaks      int8
#  13  longestKill      float16
#  14  matchDuration    int16
#  15  matchType        category
#  16  maxPlace         int8
#  17  numGroups        int8
#  18  rankPoints       int16
#  19  revives          int8
#  20  rideDistance     float16
#  21  roadKills        int8
#  22  swimDistance     float16
#  23  teamKills        int8
#  24  vehicleDestroys  int8
#  25  walkDistance     float16
#  26  weaponsAcquired  int16
#  27  winPoints        int16
#  28  winPlacePerc     float16
# dtypes: category(4), float16(6), int16(5), int8(14)
# memory usage: 498.8 MB

# %%
train['playersjoined']=train.groupby('matchId')['matchId'].transform('count')
train.head()
# Out:
#                Id         groupId         matchId  assists  boosts  \
# 0  7f96b2f878858a  4d4b580de459be  a10357fd1a4a91        0       0
# 1  eef90569b9d03c  684d5656442f9e  aeb375fc57110c        0       0
# 2  1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 3  4616d365dd2853  a930a9c79cd721  f1f1f4ef412d7e        0       0
# 4  315c96c26c9aac  de04010b3458dd  6dc8ff871e21e6        0       0
#
#    damageDealt  DBNOs  headshotKills  heals  killPlace  ...  rideDistance  \
# 0      0.00000      0              0      0         60  ...      0.000000
# 1     91.50000      0              0      0         57  ...      0.004501
# 2     68.00000      0              0      0         47  ...      0.000000
# 3     32.90625      0              0      0         75  ...      0.000000
# 4    100.00000      0              0      0         45  ...      0.000000
#
#    roadKills  swimDistance  teamKills  vehicleDestroys walkDistance  \
# 0          0      0.000000          0                0       244.75
# 1          0     11.039062          0                0      1434.00
# 2          0      0.000000          0                0       161.75
# 3          0      0.000000          0                0       202.75
# 4          0      0.000000          0                0        49.75
#
#    weaponsAcquired  winPoints  winPlacePerc  playersjoined
# 0                1       1466      0.444336             96
# 1                5          0      0.640137             91
# 2                2          0      0.775391             98
# 3                3          0      0.166748             91
# 4                2          0      0.187500             97
#
# [5 rows x 30 columns]

# %%
train['traveldistance']=train['walkDistance']+train['swimDistance']+train['rideDistance']

# %%
train['healsandboosts']=train['heals']+train['boosts']

# %% [markdown]
# # outliers

# %%
train['killingwithoutmoving']=(train['kills']>0) & (train['traveldistance']== 0)

# %%
train.drop(train[train['killingwithoutmoving']==True].index,inplace=True)

# %%
train[train['winPlacePerc'].isnull()]
# Out:
#                      Id         groupId         matchId  assists  boosts  \
# 2744604  f70c74418bb064  12dfbede33f92b  224a123c53e008        0       0
#
#          damageDealt  DBNOs  headshotKills  heals  killPlace  ...  teamKills  \
# 2744604          0.0      0              0      0          1  ...          0
#
#          vehicleDestroys  walkDistance  weaponsAcquired  winPoints  \
# 2744604                0           0.0                0          0
#
#         winPlacePerc  playersjoined  traveldistance  healsandboosts  \
# 2744604          NaN              1             0.0               0
#
#          killingwithoutmoving
# 2744604                 False
#
# [1 rows x 33 columns]

# %%
train.drop(2744604,inplace=True)

# %%
train[train['winPlacePerc'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, groupId, matchId, assists, boosts, damageDealt, DBNOs, headshotKills, heals, killPlace, killPoints, kills, killStreaks, longestKill, matchDuration, matchType, maxPlace, numGroups, rankPoints, revives, rideDistance, roadKills, swimDistance, teamKills, vehicleDestroys, walkDistance, weaponsAcquired, winPoints, winPlacePerc, playersjoined, traveldistance, healsandboosts, killingwithoutmoving]
# Index: []
#
# [0 rows x 33 columns]

# %%
train.shape
# Out:
# (4445430, 33)

# %%
train[train['walkDistance']>10000]
# Out:
#                      Id         groupId         matchId  assists  boosts  \
# 23026    8a6562381dd83f  23e638cd6eaf77  b0a804a610e9b0        0       1
# 34344    5a591ecc957393  6717370b51c247  a15d93e7165b05        0       3
# 49312    582685f487f0b4  338112cd12f1e7  d0afbf5c3a6dc9        0       4
# 68590    8c0d9dd0b4463c  c963553dc937e9  926681ea721a47        0       1
# 94400    d441bebd01db61  7e179b3366adb8  923b57b8b834cc        1       1
# ...                 ...             ...             ...      ...     ...
# 4306598  df451c374c4c9b  419e66ee851227  31bc0ed3bc2607        0       1
# 4370543  c8bdfbbb850447  fbb7a76b2b8d11  9968551b4b470a        0       0
# 4380785  9d855e5e36307d  a5ddf6aaf1e199  fbf537fe68abb0        0       3
# 4405009  dfaf3309cb27b2  f318b2e7acf3f3  7fca6dfd204455        3       8
# 4415088  0098e7009e7d40  be6e22410f07b9  122da6ef63f931        1       1
#
#          damageDealt  DBNOs  headshotKills  heals  killPlace  ...  teamKills  \
# 23026        0.00000      0              0      0         44  ...          0
# 34344       23.21875      0              0      1         34  ...          0
# 49312      117.18750      1              0      1         24  ...          0
# 68590       32.34375      0              0      1         46  ...          0
# 94400       73.06250      0              0      3         27  ...          0
# ...              ...    ...            ...    ...        ...  ...        ...
# 4306598      0.00000      0              0     11         43  ...          0
# 4370543     37.84375      0              0      1         44  ...          0
# 4380785      0.00000      0              0      5         49  ...          0
# 4405009    654.00000      6              1     11          1  ...          0
# 4415088    107.81250      1              0     10         32  ...          1
#
#          vehicleDestroys  walkDistance  weaponsAcquired  winPoints  \
# 23026                  0       13528.0                7          0
# 34344                  0       10032.0                7       1533
# 49312                  0       12408.0                3          0
# 68590                  0       11592.0                3       1563
# 94400                  0       10440.0                6       1488
# ...                  ...           ...              ...        ...
# 4306598                0       12968.0                3          0
# 4370543                0       10368.0                5       1589
# 4380785                0       11072.0                3          0
# 4405009                0       13432.0               10       1503
# 4415088                0       10992.0                4          0
#
#         winPlacePerc  playersjoined  traveldistance  healsandboosts  \
# 23026       0.816406             99         13536.0               1
# 34344       0.947266             65         10072.0               4
# 49312       0.913086             94         12448.0               5
# 68590       0.833496             96         12488.0               2
# 94400       0.819336             73         11496.0               4
# ...              ...            ...             ...             ...
# 4306598     0.852051             98         13000.0              12
# 4370543     0.877441             99         10376.0               1
# 4380785     0.750000             94         12824.0               8
# 4405009     1.000000             93         13584.0              19
# 4415088     0.678711             97         11280.0              11
#
#          killingwithoutmoving
# 23026                   False
# 34344                   False
# 49312                   False
# 68590                   False
# 94400                   False
# ...                       ...
# 4306598                 False
# 4370543                 False
# 4380785                 False
# 4405009                 False
# 4415088                 False
#
# [219 rows x 33 columns]

# %%
train.drop(train[train['walkDistance']>10000].index,inplace=True)

# %%
train[train['swimDistance']>2000]
# Out:
#                      Id         groupId         matchId  assists  boosts  \
# 177973   c2e9e5631f4e54  23213058f83abe  f01eb1073ef377        0       5
# 274258   ba5e3dfb5a0fa0  383db055216ec2  d6e13468e28ab4        0       4
# 1005337  d50c9d0e65fe2a  4996575c11abcb  668402592429f8        0       1
# 1195818  f811de9de80b70  d08ddf7beb6252  8a48703ab52ec8        0       7
# 1227362  a33e917875c80e  5b72674b42712b  5fb0d8b1fc16cf        0       1
# 1889163  bd8cc3083a9923  1d5d17140d6fa4  8e2e6022d6e5c8        0       0
# 2065940  312ccbb27b99aa  47c7f4d69e2fb1  b4b11756321f3a        1       3
# 2327586  8773d0687c6aae  b17f46f9f6666c  56ee5897512c86        3       1
# 2784855  a8653b87e83892  383db055216ec2  d6e13468e28ab4        1       4
# 3359439  3713b36e1ba9e1  1f7aed9240864a  584447ed875c85        0       0
# 3513522  aff482b8c08486  383db055216ec2  d6e13468e28ab4        0       4
# 4132225  2496e3223a8b5d  78980ab36f7642  23ec7dd5546022        0       0
#
#          damageDealt  DBNOs  headshotKills  heals  killPlace  ...  teamKills  \
# 177973      78.12500      1              0      1         47  ...          0
# 274258      53.31250      0              0     16         39  ...          0
# 1005337    503.00000      4              3      1          6  ...          0
# 1195818    352.25000      3              1      6          4  ...          0
# 1227362    589.00000      3              1      1         46  ...          0
# 1889163      0.00000      0              0      0         47  ...          0
# 2065940     49.59375      0              0      5         48  ...          0
# 2327586    474.50000      2              0      0          7  ...          0
# 2784855    844.00000      5              5      2          2  ...          0
# 3359439      0.00000      0              0      0         77  ...          0
# 3513522    109.81250      0              0     18         40  ...          0
# 4132225      0.00000      0              0      0         83  ...          0
#
#          vehicleDestroys  walkDistance  weaponsAcquired  winPoints  \
# 177973                 0   1002.000000                4       1466
# 274258                 0   2276.000000                5          0
# 1005337                0   4692.000000                5       1516
# 1195818                0    415.000000               10       1499
# 1227362                0    995.500000                9          0
# 1889163                0   1966.000000                3          0
# 2065940                0   4296.000000                8       1492
# 2327586                0      7.546875                6          0
# 2784855                0   4688.000000                4          0
# 3359439                0   1750.000000                0       1518
# 3513522                0   3972.000000                5          0
# 4132225                0   1534.000000                0          0
#
#         winPlacePerc  playersjoined  traveldistance  healsandboosts  \
# 177973      0.958984             98          3298.0               6
# 274258      0.959961             94         10112.0              20
# 1005337     1.000000             88         10736.0               2
# 1195818     1.000000             98          3084.0              13
# 1227362     1.000000             86          4820.0               2
# 1889163     0.583496             87          5312.0               0
# 2065940     0.851074             96          9896.0               8
# 2327586     1.000000             91          2396.0               1
# 2784855     0.959961             94          9928.0               6
# 3359439     0.214355             96          4088.0               0
# 3513522     0.959961             94          9808.0              22
# 4132225     0.085083             95          3916.0               0
#
#          killingwithoutmoving
# 177973                  False
# 274258                  False
# 1005337                 False
# 1195818                 False
# 1227362                 False
# 1889163                 False
# 2065940                 False
# 2327586                 False
# 2784855                 False
# 3359439                 False
# 3513522                 False
# 4132225                 False
#
# [12 rows x 33 columns]

# %%
train.drop(train[train['swimDistance']>2000].index,inplace=True)

# %%
train[train['rideDistance']>20000]
# Out:
#                      Id         groupId         matchId  assists  boosts  \
# 28588    6260f7c49dc16f  b24589f02eedd7  6ebea3b4f55b4a        0       0
# 63015    adb7dae4d0c10a  8ede98a241f30a  8b36eac66378e4        0       0
# 70507    ca6fa339064d67  f7bb2e30c3461f  3bfd8d66edbeff        0       0
# 72763    198e5894e68ff4  ccf47c82abb11f  d92bf8e696b61d        0       0
# 95276    c3fabfce7589ae  15529e25aa4a74  d055504340e5f4        0       7
# ...                 ...             ...             ...      ...     ...
# 4270943  7a9ef7be64e37e  4873e2b0d83c69  653dc89930fdc2        0       7
# 4301013  4985541631d98b  d0e454dc0ac3cf  3f819651e3c666        0       0
# 4386384  5d472a1fcad9c9  f94054ff58eab0  ad37f12700c1ba        0       0
# 4404738  810bcb9e6ff249  605266536c0f45  7f817462a20c19        0       1
# 4440261  9a7c448670f199  04b0e435abc817  a4063f40804b24        0       0
#
#          damageDealt  DBNOs  headshotKills  heals  killPlace  ...  teamKills  \
# 28588       99.18750      0              0      1         30  ...          0
# 63015        0.00000      0              0      0         55  ...          0
# 70507      100.00000      0              0      0         26  ...          0
# 72763        0.00000      0              0      0         46  ...          1
# 95276      778.00000      0              1      2          2  ...          0
# ...              ...    ...            ...    ...        ...  ...        ...
# 4270943    560.00000      0              3      3          2  ...          0
# 4301013     15.46875      0              0      0         53  ...          1
# 4386384      0.00000      0              0      0         47  ...          0
# 4404738     84.37500      0              0      0         38  ...          1
# 4440261      0.00000      0              0      0         45  ...          0
#
#          vehicleDestroys  walkDistance  weaponsAcquired  winPoints  \
# 28588                  0    376.500000                6          0
# 63015                  0    185.375000                0          0
# 70507                  0    467.500000                3          0
# 72763                  0    687.000000                9          0
# 95276                  0    923.000000                6          0
# ...                  ...           ...              ...        ...
# 4270943                1    969.000000                5       1576
# 4301013                0     50.250000                0       1489
# 4386384                0    470.000000                3       1500
# 4404738                0    114.687500                0       1523
# 4440261                0     23.765625                0          0
#
#         winPlacePerc  playersjoined  traveldistance  healsandboosts  \
# 28588       0.642090             96         26320.0               1
# 63015       0.537598             94         22080.0               0
# 70507       0.887695             99         28912.0               0
# 72763       0.791504             97         21200.0               0
# 95276       0.978516             94         26736.0               9
# ...              ...            ...             ...             ...
# 4270943     0.989746             99         33408.0              10
# 4301013     0.500000             87         25072.0               0
# 4386384     0.777832             91         26688.0               0
# 4404738     0.644043             74         24336.0               1
# 4440261     0.747559             96         31712.0               0
#
#          killingwithoutmoving
# 28588                   False
# 63015                   False
# 70507                   False
# 72763                   False
# 95276                   False
# ...                       ...
# 4270943                 False
# 4301013                 False
# 4386384                 False
# 4404738                 False
# 4440261                 False
#
# [150 rows x 33 columns]

# %%
train.drop(train[train['rideDistance']>20000].index,inplace=True)

# %%
train[train['longestKill']>1000]
# Out:
#                      Id         groupId         matchId  assists  boosts  \
# 240005   41c2f5c0699807  9faecf87ab4275  634edab75860b3        5       0
# 324313   ef390c152bcc3d  30fd444be3bbc1  4f7f8d6cf558b4        2       0
# 803632   4e7e6c74e3c57d  94698690918933  da91b0c3d875f8        0       0
# 895411   1f5ba6e0cfb968  512ea24b831be3  5fb0d8b1fc16cf        4       0
# 1172437  303a93cfa1f46c  8795d39fd0df86  9c8962b58bb3e3        2       1
# 1209416  528659ff1c1aec  7d1ba83423551d  ea9386587d5888        0       6
# 1642712  91966848e08e2f  0ee4fbd27657c9  17dea22cefe62a        3       2
# 2015559  5ff0c1a9fab2ba  2d8119b1544f87  904cecf36217df        3       3
# 2122128  42df3102cb540b  7d9b2be15b355b  610d78f3affd2e        5       0
# 2152425  4b9f61bac5eb0a  bc717b964f3bbe  838cb9a3c94598        3       0
# 2592718  24e0fec84c18e9  8404855ca02e48  e886a8ebb702cf        7       0
# 2981715  7f77051c7cef52  d6579a630399b5  4784f7d9a06b51        3       5
# 3081503  f19a76e8d7ac52  624d65c529f87c  de19b70121c40f        3       0
# 3255171  5524c154448425  674195558ad41b  db6f6d1f0d4904        1       0
# 3304284  d0c286ce498e17  17fdd45e612bab  3eaaa2f7a360fe        7       0
# 3320960  0040e53dfe7b5d  650661c2351eb7  2daabf3a7852e6        0       0
# 3552532  db638834c62f6f  0614b611d6a935  ff80300f8262f5        2       0
# 4332473  d8857d3d7e31b6  085de7a36897e6  42f997c16d8a0e        5       0
#
#          damageDealt  DBNOs  headshotKills  heals  killPlace  ...  teamKills  \
# 240005       1284.00      8              5      7         18  ...          0
# 324313       1028.00      0              0      0          9  ...          0
# 803632        196.75      0              0      0         51  ...          0
# 895411       1012.00     11              5      0          5  ...          0
# 1172437       329.25      0              0      2         45  ...          0
# 1209416      1640.00      0              7      0          1  ...          0
# 1642712      2104.00      0              4     11         11  ...          0
# 2015559      1302.00      0              6      5         15  ...          0
# 2122128      2500.00      0              7      1          2  ...          2
# 2152425       945.50      0              0      0         11  ...          0
# 2592718      1684.00      0              4      7         11  ...          0
# 2981715      1025.00      5              2      5          2  ...          0
# 3081503      1038.00      0              0      0         32  ...          0
# 3255171      1355.00      0              2      0          9  ...          1
# 3304284      2330.00      0              2      0          2  ...          1
# 3320960       399.00      2              0      6         14  ...          0
# 3552532       517.00      0              0      0         10  ...          2
# 4332473      1685.00     11              3     18          8  ...          0
#
#          vehicleDestroys  walkDistance  weaponsAcquired  winPoints  \
# 240005                 0        48.875               38       1500
# 324313                 0      1264.000               26          0
# 803632                 0      1074.000               22          0
# 895411                 0       569.500               18          0
# 1172437                0       832.500                9       1500
# 1209416                0      2848.000                4       1500
# 1642712                0       235.250               41          0
# 2015559                0       133.250               43          0
# 2122128                0       464.500               52          0
# 2152425                0       844.500               14          0
# 2592718                0      1115.000               54       1500
# 2981715                0      3998.000                7          0
# 3081503                0       270.000               28       1500
# 3255171                0      1039.000               37          0
# 3304284                0        68.000               32          0
# 3320960                0      1511.000               45       1500
# 3552532                0      1310.000                6          0
# 4332473                0       523.500               35       1500
#
#         winPlacePerc  playersjoined  traveldistance  healsandboosts  \
# 240005      0.538574             29          48.875               7
# 324313      1.000000             51        2980.000               0
# 803632      0.000000             61        3158.000               0
# 895411      0.909180             86         569.500               0
# 1172437     0.285645             58         832.500               3
# 1209416     0.941406             52        2848.000               6
# 1642712     0.500000             28         235.250              13
# 2015559     0.600098             42         133.250               8
# 2122128     0.000000             10         464.500               1
# 2152425     0.571289             60         844.500               0
# 2592718     0.571289             26        4852.000               7
# 2981715     1.000000             93        4086.000              10
# 3081503     0.856934             57         270.000               0
# 3255171     0.579102             21        1039.000               0
# 3304284     1.000000             53          68.000               0
# 3320960     0.000000             15        5480.000               6
# 3552532     0.000000             30        1345.000               0
# 4332473     0.909180             26         523.500              18
#
#          killingwithoutmoving
# 240005                  False
# 324313                  False
# 803632                  False
# 895411                  False
# 1172437                 False
# 1209416                 False
# 1642712                 False
# 2015559                 False
# 2122128                 False
# 2152425                 False
# 2592718                 False
# 2981715                 False
# 3081503                 False
# 3255171                 False
# 3304284                 False
# 3320960                 False
# 3552532                 False
# 4332473                 False
#
# [18 rows x 33 columns]

# %%
train.drop(train[train['longestKill']>1000].index,inplace=True)

# %%
train[train['kills']>30]
# Out:
#                      Id         groupId         matchId  assists  boosts  \
# 57978    9d8253e21ccbbd  ef7135ed856cd8  37f05e2a01015f        9       0
# 87793    45f76442384931  b3627758941d34  37f05e2a01015f        8       0
# 156599   746aa7eabf7c86  5723e7d8250da3  f900de1ec39fa5       21       0
# 160254   15622257cb44e2  1a513eeecfe724  db413c7c48292c        1       0
# 180189   1355613d43e2d0  f863cd38c61dbf  39c442628f5df5        5       0
# ...                 ...             ...             ...      ...     ...
# 4021018  1f1c3dda0296df  7c95f475fd2cdb  a9e84c456cc859        6       0
# 4127904  f699c842c5dfab  9d69e4e697d296  1ac375e4121651        5       0
# 4148675  5283367a7f8d06  35b9b765110fd2  f900de1ec39fa5       12       0
# 4235682  6874be9215646b  af1d17223258d0  0f09bd72c4ba97        1       0
# 4273754  2a4c8d7cdb0361  8ee08f3d84dc3a  17dea22cefe62a        6       0
#
#          damageDealt  DBNOs  headshotKills  heals  killPlace  ...  teamKills  \
# 57978         3724.0      0              7      0          2  ...          0
# 87793         3088.0      0              8     27          3  ...          0
# 156599        5480.0      0             12      7          4  ...          0
# 160254        4032.0      0             40      0          1  ...          1
# 180189        3172.0      0              6     15          1  ...          0
# ...              ...    ...            ...    ...        ...  ...        ...
# 4021018       3406.0      0              8     10          2  ...          0
# 4127904       3420.0     39             20      1          1  ...          0
# 4148675       3050.0      0              5      4          7  ...          0
# 4235682       3006.0      0              9     18          2  ...          0
# 4273754       5296.0      0              5     11          2  ...          0
#
#          vehicleDestroys  walkDistance  weaponsAcquired  winPoints  \
# 57978                  0     48.812500               48       1500
# 87793                  0    780.500000               45       1500
# 156599                 0     23.703125               61          0
# 160254                 0    718.500000               16       1500
# 180189                 0     71.500000               41          0
# ...                  ...           ...              ...        ...
# 4021018                0   2264.000000               40          0
# 4127904                0    319.250000               29       1500
# 4148675                0    123.812500               89          0
# 4235682                0    557.500000               20       1500
# 4273754                0    242.875000               54          0
#
#         winPlacePerc  playersjoined  traveldistance  healsandboosts  \
# 57978       0.856934             16       48.812500               0
# 87793       1.000000             16      780.500000              27
# 156599      0.700195             11       23.703125               7
# 160254      1.000000             62      718.500000               0
# 180189      1.000000             11       71.500000              15
# ...              ...            ...             ...             ...
# 4021018     0.916504             13     3816.000000              10
# 4127904     0.750000             36      319.250000               1
# 4148675     0.399902             11      123.812500               4
# 4235682     0.428711             28      557.500000              18
# 4273754     0.856934             28      242.875000              11
#
#          killingwithoutmoving
# 57978                   False
# 87793                   False
# 156599                  False
# 160254                  False
# 180189                  False
# ...                       ...
# 4021018                 False
# 4127904                 False
# 4148675                 False
# 4235682                 False
# 4273754                 False
#
# [95 rows x 33 columns]

# %%
train.drop(train[train['kills']>30].index,inplace=True)

# %%
train[train['roadKills']>12]
# Out:
#                      Id         groupId         matchId  assists  boosts  \
# 2733926  c3e444f7d1289f  489dd6d1f2b3bb  4797482205aaa4        0       0
# 2890740  a3438934e3e535  1081c315a80d14  fe744430ac0070        0       8
#
#          damageDealt  DBNOs  headshotKills  heals  killPlace  ...  teamKills  \
# 2733926       1246.0      0              0      0          1  ...          0
# 2890740       2074.0      0              1     11          1  ...          0
#
#          vehicleDestroys  walkDistance  weaponsAcquired  winPoints  \
# 2733926                0        1277.0                0       1371
# 2890740                0        3150.0                4       1568
#
#         winPlacePerc  playersjoined  traveldistance  healsandboosts  \
# 2733926     0.428711             92          1282.0               0
# 2890740     1.000000             38          5876.0              19
#
#          killingwithoutmoving
# 2733926                 False
# 2890740                 False
#
# [2 rows x 33 columns]

# %%
train.drop(train[train['roadKills']>12].index,inplace=True)

# %%
train[train['weaponsAcquired']>70]
# Out:
#                      Id         groupId         matchId  assists  boosts  \
# 104825   4fe1c1b84d0e4c  62bc19a85c2ed8  17dea22cefe62a        3       0
# 180523   aa4031a9ba3fbf  04f57c0cfb1306  5921b55b9e96b5        7       0
# 233643   7c8c83f5f97d0f  b33b210a52a2f8  2e8a0917a71c43        0       0
# 588387   c58e3e0c2ba678  3d3e6100c07ff0  d04dbb98249f76        0       1
# 1004726  a77a0e7230bdca  1a79c284fd3661  e024bf51bf1799        1       0
# 1437471  8f0c855d23e4cd  679c3316056de8  fbaf1b3ae1d884        1       0
# 1449293  db54cf45b9ed1c  898fccaeeb041d  484b4ae51fe80f        0       0
# 1592744  634a224c53444e  75fa7591d1538c  f900de1ec39fa5        9       0
# 1834515  e927e9020f7e0d  60d6b714a7308f  8e265af296007b        1       1
# 2373240  a8c150d5d3d3e2  6e1c8c5f91e060  f900de1ec39fa5       12       0
# 2442962  438cabaa5dfbdd  596c155c524725  8e0bbeec19a929        0       0
# 2544613  1a885fe0b06a5b  4d26ef2dc336bb  e024bf51bf1799       13       0
# 2743408  afcb46681b909f  3715298b7eea9c  4dd4d42772464f        0       4
# 2749693  940b52bf12805a  4757d102ca4fbf  7ecae2cedc064f        1       3
# 2797867  da68d2812229a8  536975608768ed  fbbdc018f4b771        0       0
# 2804693  f460ec55a474d2  83e49cbcc26dca  17c643ab998ecb        6       0
# 2973445  c069dfaf8bf6d5  448f1c0fbe93b1  e19210730c7ed7        0       2
# 2977084  fedf03626cf9f2  11d036be4e05e5  ab1308cd283e8a        1       4
# 2982525  3f2bcf53b108c4  2dbc013e849f5a  1df2560f0937ab        0       1
# 3142858  866c59adfeaf40  1c58119dccc248  6680c7c3d17d48        8       2
# 3230315  e5e7a97d2922c3  efbb85dcb47925  6680c7c3d17d48        9       1
# 3256470  9379ea63194a7a  a940cad376575d  f8ba62144445f1        0       2
# 3291955  a0acd251db3984  fb202d06125825  5921b55b9e96b5       17       0
# 3405716  bf0f64b40f6975  bbf007abbbe303  f900de1ec39fa5        8       0
# 3701150  7458f6f2b99fab  a3dd60307a9c94  ba1b3603d0f840        1       1
# 3951710  a55a2d4f4e4852  d9bdbeaeab7143  2518cb67372cb4        0       0
# 3997360  a5e041e5a378b2  418f11cd024cbc  17c643ab998ecb        7       0
# 4022031  bc2b0e0fc30da4  b5fd53075672cf  281a05959b96e6        1       1
# 4288517  ae95a536f9b824  3bf6589447e952  f900de1ec39fa5       11       0
# 4381091  97bf68b6df93c2  afc31d91549183  17c643ab998ecb        7       0
#
#          damageDealt  DBNOs  headshotKills  heals  killPlace  ...  teamKills  \
# 104825   2652.000000      0              3      3          9  ...          0
# 180523   2868.000000      0              2      5          5  ...          0
# 233643     67.125000      0              0      0         44  ...          0
# 588387    175.250000      1              0      2         48  ...          0
# 1004726   881.500000      0              1      0         19  ...          1
# 1437471   100.000000      0              0      0         24  ...          0
# 1449293     0.000000      0              0      0         54  ...          0
# 1592744  1726.000000      0              3      0          9  ...          0
# 1834515    26.453125      0              0      1         51  ...          0
# 2373240  1746.000000      0              1      1         11  ...          0
# 2442962     0.000000      0              0      0         56  ...          0
# 2544613  3338.000000      0              9      4          9  ...          0
# 2743408   186.875000      2              0      2         18  ...          1
# 2749693   379.000000      2              0      5          7  ...          0
# 2797867     0.000000      0              0      0         58  ...          0
# 2804693  1597.000000      0              5      9          8  ...          0
# 2973445   371.250000      4              3      2          3  ...          0
# 2977084   683.500000      5              0      8          3  ...          0
# 2982525    85.875000      0              0      2         55  ...          0
# 3142858  2884.000000      0              7      7          7  ...          0
# 3230315  1606.000000      0              3      6         19  ...          0
# 3256470     0.000000      0              0      0         39  ...          0
# 3291955  2022.000000      0              2      3         11  ...          0
# 3405716  2614.000000      0              9      4          8  ...          1
# 3701150   103.687500      1              0      0         25  ...          0
# 3951710    96.750000      0              0      0         45  ...          0
# 3997360  1868.000000      0              3     12          6  ...          0
# 4022031   240.750000      1              0      3         28  ...          0
# 4288517  1534.000000      0              5      0         10  ...          0
# 4381091  2360.000000      0              2     11          5  ...          1
#
#          vehicleDestroys  walkDistance  weaponsAcquired  winPoints  \
# 104825                 0   1024.000000               71          0
# 180523                 0   1436.000000               72          0
# 233643                 0   1307.000000              128       1577
# 588387                 0   1687.000000               80          0
# 1004726                0   1479.000000               72          0
# 1437471                0   2400.000000              102          0
# 1449293                0    653.000000               95          0
# 1592744                0    981.000000               94          0
# 1834515                0   2836.000000               96          0
# 2373240                0    276.000000               96          0
# 2442962                0    807.500000               95          0
# 2544613                0   1183.000000               72          0
# 2743408                0   1643.000000              167       1452
# 2749693                0   3338.000000              177       1711
# 2797867                0   1235.000000              153          0
# 2804693                0    936.000000               75       1500
# 2973445                0   2098.000000               87          0
# 2977084                0   3084.000000               85       1550
# 2982525                0   2112.000000              236       1553
# 3142858                0    955.500000               76          0
# 3230315                0   1000.000000               80          0
# 3256470                0   2020.000000               74       1464
# 3291955                0     29.578125               78          0
# 3405716                0    381.250000               88          0
# 3701150                0   3208.000000               73       1636
# 3951710                0   2798.000000               81       1447
# 3997360                0    557.000000               73       1500
# 4022031                0   2328.000000               97       1671
# 4288517                0   1349.000000               92          0
# 4381091                0    295.250000               73       1500
#
#         winPlacePerc  playersjoined  traveldistance  healsandboosts  \
# 104825      0.928711             28     4644.000000               3
# 180523      0.733398             16     3108.000000               5
# 233643      0.710938             91     3188.000000               0
# 588387      0.750000             98     1687.000000               3
# 1004726     0.000000             19     1679.000000               0
# 1437471     0.893066             97     5300.000000               0
# 1449293     0.560059             80      653.000000               0
# 1592744     0.199951             11     2888.000000               0
# 1834515     0.919922             95     2836.000000               2
# 2373240     0.000000             11      276.000000               1
# 2442962     0.500000             91      807.500000               0
# 2544613     0.555664             19     2812.000000               4
# 2743408     0.795410             90     3318.000000               6
# 2749693     0.884766             98     3642.000000               8
# 2797867     0.546387             98     1235.000000               0
# 2804693     0.000000              8      936.000000               9
# 2973445     0.666504             94     2510.000000               4
# 2977084     1.000000             92     3534.000000              12
# 2982525     0.678711             99     6888.000000               3
# 3142858     0.643066             47      986.500000               9
# 3230315     0.428711             47     2888.000000               7
# 3256470     0.790527             81     2020.000000               2
# 3291955     0.333252             16       29.578125               3
# 3405716     0.300049             11      381.250000               4
# 3701150     0.807617             90     4712.000000               1
# 3951710     0.871094            100     6608.000000               0
# 3997360     0.166748              8      557.000000              12
# 4022031     0.978516             96     2464.000000               4
# 4288517     0.099976             11     2780.000000               0
# 4381091     0.333252              8      295.250000              11
#
#          killingwithoutmoving
# 104825                  False
# 180523                  False
# 233643                  False
# 588387                  False
# 1004726                 False
# 1437471                 False
# 1449293                 False
# 1592744                 False
# 1834515                 False
# 2373240                 False
# 2442962                 False
# 2544613                 False
# 2743408                 False
# 2749693                 False
# 2797867                 False
# 2804693                 False
# 2973445                 False
# 2977084                 False
# 2982525                 False
# 3142858                 False
# 3230315                 False
# 3256470                 False
# 3291955                 False
# 3405716                 False
# 3701150                 False
# 3951710                 False
# 3997360                 False
# 4022031                 False
# 4288517                 False
# 4381091                 False
#
# [30 rows x 33 columns]

# %%
train.drop(train[train['weaponsAcquired']>70].index,inplace=True)

# %%
train[train['heals']>35]
# Out:
#                      Id         groupId         matchId  assists  boosts  \
# 18405    63ab976895d860  927eeba5614c4f  69473402649f11        0       2
# 54463    069ddee7c9d26a  58ab5a1ce8e06f  942416b6caf21e        1       4
# 67676    9141a9dd94680e  10e9baaea7ee52  1746a49f176549        0       3
# 100152   6c814c89c4e063  43f1edf6402ad5  7be6241e8a3be8        0       6
# 112499   3a730c969a78ee  96774752376c8f  0998fc79a99bae        0       1
# ...                 ...             ...             ...      ...     ...
# 4369025  a3481955ab300b  95e725d4ee6d9c  1b17310cd1ad8e        1       3
# 4394898  4829aab2dd2904  1eb8d05b80bb29  aeeccc37519d2a        3       3
# 4397805  703ce5805efed7  b84c7dd65f03cd  d8fa2223c98979        0       1
# 4436938  ecf4468be5302c  8a934182175702  4b1eb1af720e23        0       3
# 4438304  97a7862329ed17  7a0f54f8743b9f  b6997081e44d95        0       2
#
#          damageDealt  DBNOs  headshotKills  heals  killPlace  ...  teamKills  \
# 18405          0.000      0              0     47         43  ...          0
# 54463        182.000      0              1     43         21  ...          0
# 67676         97.000      0              0     37         45  ...          0
# 100152         0.000      0              0     37         43  ...          0
# 112499       110.000      0              1     38         29  ...          0
# ...              ...    ...            ...    ...        ...  ...        ...
# 4369025      313.750      1              2     47          4  ...          0
# 4394898     1173.000     10              1     36          1  ...          0
# 4397805       44.500      0              0     62         44  ...          0
# 4436938        0.000      0              0     36         42  ...          0
# 4438304       52.375      0              0     38         45  ...          0
#
#          vehicleDestroys  walkDistance  weaponsAcquired  winPoints  \
# 18405                  0        1387.0                6          0
# 54463                  0        2792.0                7          0
# 67676                  0        3504.0                3          0
# 100152                 0        2960.0                4       1591
# 112499                 0        1140.0                6          0
# ...                  ...           ...              ...        ...
# 4369025                0        1103.0                4       1523
# 4394898                0        1995.0                8          0
# 4397805                0        2628.0                6          0
# 4436938                0        2386.0                8          0
# 4438304                0        1831.0                3          0
#
#         winPlacePerc  playersjoined  traveldistance  healsandboosts  \
# 18405       0.937012             96          6856.0              49
# 54463       0.961426             93          3084.0              47
# 67676       0.897461             89          5324.0              40
# 100152      0.867188             99          3018.0              43
# 112499      0.729004             98          5364.0              39
# ...              ...            ...             ...             ...
# 4369025     0.744141             86          1103.0              50
# 4394898     1.000000             93          4496.0              39
# 4397805     0.836914             97          2628.0              63
# 4436938     0.868164             92          2834.0              39
# 4438304     0.879883             90          3736.0              40
#
#          killingwithoutmoving
# 18405                   False
# 54463                   False
# 67676                   False
# 100152                  False
# 112499                  False
# ...                       ...
# 4369025                 False
# 4394898                 False
# 4397805                 False
# 4436938                 False
# 4438304                 False
#
# [273 rows x 33 columns]

# %%
train.drop(train[train['heals']>35].index,inplace=True)

# %%
train.shape
# Out:
# (4444631, 33)

# %% [markdown]
# # Prediction modeling

# %%
df=pd.concat([train,test],ignore_index=True)

# %%
df.shape
# Out:
# (6378805, 33)

# %%
enc_df2 = pd.get_dummies(df[["matchType"]])
df.drop(['matchType'],axis=1,inplace=True)
#df.rename(columns={0.0:'Ungraduated',1.0:'Graduated'},inplace=True)
df = df.join(enc_df2)

df.drop(['Id','groupId','matchId'],axis=1,inplace=True)
trainx = df.iloc[:4444630]
testx = df.iloc[4444631:].fillna(0)
y=trainx["winPlacePerc"]
X = trainx.drop(["winPlacePerc"],axis=1)
X_test = testx.drop(["winPlacePerc"],axis=1)

from sklearn.model_selection import train_test_split
#xtrain,xtest,ytrain,ytest = train_test_split(X,y,test_size=0.4,random_state=42)
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler

prep = MinMaxScaler()

# %%
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
y.fillna(0,inplace=True)
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py:4523: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
X_train,X_val,y_train,y_val = train_test_split(X,y,test_size=0.4,random_state=42)

# %%
DTree_clf = DecisionTreeRegressor()
DTree_clf.fit(X, y)
# Out:
# DecisionTreeRegressor()

# %%
DTree_pred = DTree_clf.predict(X_test)

# %%
DTree_pred[:20]
# Out:
# array([0.        , 0.54882812, 0.        , 0.        , 0.5       ,
#        0.        , 0.54541016, 0.        , 0.        , 0.38110352,
#        0.48950195, 0.23083496, 0.77783203, 0.97851562, 0.01589966,
#        0.39135742, 0.29638672, 0.        , 0.        , 0.1071167 ])

# %%
X_test.shape
# Out:
# (1934174, 44)

# %%
test.shape
# Out:
# (1934174, 28)

# %%
test.tail()
# Out:
#                      Id         groupId         matchId  assists  boosts  \
# 1934169  a316c3a13887d5  80e82180c90951  f276da5fd73536        1       2
# 1934170  5312146b27d875  147264a127c56e  fb77cbfe094a6b        0       0
# 1934171  fc8818b5b32ad3  7bbb4779ebedd5  efb74d5f6e9779        0       0
# 1934172  a0f91e35f8458f  149a506a64c2b1  3a2cf335bc302f        1       2
# 1934173  3696fc9f3a42b2  c770d7feaf020f  9d4e2b6d506fd0        0       0
#
#          damageDealt  DBNOs  headshotKills  heals  killPlace  ...  rankPoints  \
# 1934169   381.000000      3              0      7          4  ...          -1
# 1934170     0.000000      0              0      0         64  ...          -1
# 1934171    91.937500      0              0      3         24  ...        1482
# 1934172   138.625000      0              0     12         25  ...        1456
# 1934173    19.796875      0              0      0         86  ...          -1
#
#          revives  rideDistance  roadKills  swimDistance teamKills  \
# 1934169        1           0.0          0      0.000000         0
# 1934170        0           0.0          0      0.000000         0
# 1934171        0           0.0          0      7.796875         1
# 1934172        1           0.0          0      0.000000         0
# 1934173        0           0.0          0      0.000000         0
#
#          vehicleDestroys  walkDistance  weaponsAcquired  winPoints
# 1934169                0      1799.000                5       1526
# 1934170                0      1195.000                3       1496
# 1934171                0      3328.000                3          0
# 1934172                0      1893.000                4          0
# 1934173                0        68.875                0       1551
#
# [5 rows x 28 columns]

# %%
X_test.head()
# Out:
#          assists  boosts  damageDealt  DBNOs  headshotKills  heals  killPlace  \
# 4444631        0       0     51.46875      0              0      0         73
# 4444632        0       4    179.12500      0              0      2         11
# 4444633        1       0     23.40625      0              0      4         49
# 4444634        0       0     65.50000      0              0      0         54
# 4444635        0       4    330.25000      1              2      1          7
#
#          killPoints  kills  killStreaks  ...  matchType_normal-duo  \
# 4444631           0      0            0  ...                     0
# 4444632           0      2            1  ...                     0
# 4444633           0      0            0  ...                     0
# 4444634           0      0            0  ...                     0
# 4444635           0      3            1  ...                     0
#
#          matchType_normal-duo-fpp  matchType_normal-solo  \
# 4444631                         0                      0
# 4444632                         0                      0
# 4444633                         0                      0
# 4444634                         0                      0
# 4444635                         0                      0
#
#          matchType_normal-solo-fpp  matchType_normal-squad  \
# 4444631                          0                       0
# 4444632                          0                       0
# 4444633                          0                       0
# 4444634                          0                       0
# 4444635                          0                       0
#
#          matchType_normal-squad-fpp  matchType_solo  matchType_solo-fpp  \
# 4444631                           0               0                   0
# 4444632                           0               0                   0
# 4444633                           0               0                   0
# 4444634                           0               0                   0
# 4444635                           0               0                   0
#
#          matchType_squad  matchType_squad-fpp
# 4444631                0                    1
# 4444632                0                    0
# 4444633                0                    1
# 4444634                0                    0
# 4444635                0                    1
#
# [5 rows x 44 columns]

# %%
output = pd.DataFrame({'Id':test.Id,'winPlacePerc':DTree_pred})

# %%
output
# Out:
#                      Id  winPlacePerc
# 0        9329eb41e215eb      0.000000
# 1        639bd0dcd7bda8      0.548828
# 2        63d5c8ef8dfe91      0.000000
# 3        cf5b81422591d1      0.000000
# 4        ee6a295187ba21      0.500000
# ...                 ...           ...
# 1934169  a316c3a13887d5      0.625000
# 1934170  5312146b27d875      0.033295
# 1934171  fc8818b5b32ad3      0.222168
# 1934172  a0f91e35f8458f      0.694336
# 1934173  3696fc9f3a42b2      0.000000
#
# [1934174 rows x 2 columns]
